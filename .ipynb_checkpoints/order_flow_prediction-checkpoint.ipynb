# %%
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('xbtusdt_orderbook1.csv', index_col=0)
df2 = pd.read_csv('xbtusdt_orderbook2.csv', index_col=0)
df3 = pd.read_csv('xbtusdt_orderbook3.csv', index_col=0)

# %%
df1[['ask_p_0', 'bid_p_0']].plot()
df2[['ask_p_0', 'bid_p_0']].plot()
df3[['ask_p_0', 'bid_p_0']].plot()

# %%
import numpy as np

def feature(df):
    for i in range(10):
        ind = str(i)
        df['spreed_'+ind] = df['ask_p_'+ind] - df['bid_p_'+ind]
        df['mid_p'+ind] = (df['ask_p_'+ind] + df['bid_p_'+ind]) / 2

    for i in range(9):
        ind = str(i+1)
        df['ask_p_diff_'+ind+'_0'] = df['ask_p_'+ind] - df['ask_p_0']
        df['bid_p_diff_'+ind+'_0'] = df['bid_p_'+ind] - df['bid_p_0']
        ind1 = str(i)
        df['ask_p_diff_'+ind+'_'+ind1] = df['ask_p_'+ind] - df['ask_p_'+ind1]
        df['bid_p_diff_'+ind+'_'+ind1] = df['bid_p_'+ind] - df['bid_p_'+ind1]

    l1, l2, l3, l4 = [], [], [], []
    for i in range(10):
        ind = str(i)
        l1.append('ask_p_'+ind)
        l2.append('bid_p_'+ind)
        l3.append('ask_vol_'+ind)
        l4.append('bid_vol_'+ind)
    df['ask_p_mean'] = df[l1].mean(axis=1)
    df['bid_mean'] = df[l2].mean(axis=1)
    df['ask_vol_mean'] = df[l3].mean(axis=1)
    df['bid_vol_mean'] = df[l4].mean(axis=1)

    l = []
    template = 'spreed_{0}'
    for i in range(10):
        l.append(template.format(i))
    df['accum_spreed'] = df[l].sum(axis=1)

    for i in range(10):
        ind = str(i)
        df['spreed_vol_'+ind] = df['ask_vol_'+ind] - df['bid_vol_'+ind]
    l = []
    template = 'spreed_vol_{0}'
    for i in range(10):
        l.append(template.format(i))
    df['accum_spreed_vol'] = df[l].sum(axis=1)
    
    df['y'] = np.where(df['mid_p0'] > df['mid_p0'].shift(1) , 1, 0)
    df['y'] = np.where(df['mid_p0'] < df['mid_p0'].shift(1) , -1, df['y'])
    return df

# %%
df1 = feature(df1)
df2 = feature(df2)
df3 = feature(df3)

# %%
df1['y'].value_counts()
# Out:
#  0    16809
#  1      239
# -1      235
# Name: y, dtype: int64

# %%
df2['y'].value_counts()
# Out:
#  0    16894
#  1      198
# -1      188
# Name: y, dtype: int64

# %%
df3['y'].value_counts()
# Out:
#  0    17015
#  1      147
# -1      118
# Name: y, dtype: int64

# %%
df = pd.concat([df1, df2, df3])
df.describe()
# Out:
#             ask_p_0       ask_p_1       ask_p_2       ask_p_3       ask_p_4  \
# count  51843.000000  51843.000000  51843.000000  51843.000000  51843.000000
# mean    6337.703335   6338.203595   6338.703721   6339.203808   6339.703837
# std       15.738355     15.738290     15.738528     15.738618     15.738652
# min     6303.500000   6304.000000   6304.500000   6305.000000   6305.500000
# 25%     6330.000000   6330.500000   6331.000000   6331.500000   6332.000000
# 50%     6339.500000   6340.000000   6340.500000   6341.000000   6341.500000
# 75%     6348.500000   6349.000000   6349.500000   6350.000000   6350.500000
# max     6382.000000   6383.000000   6386.000000   6386.500000   6387.000000
#
#             ask_p_5       ask_p_6       ask_p_7       ask_p_8       ask_p_9  \
# count  51843.000000  51843.000000  51843.000000  51843.000000  51843.000000
# mean    6340.203866   6340.703962   6341.203962   6341.703962   6342.203962
# std       15.738657     15.738846     15.738846     15.738846     15.738846
# min     6306.000000   6306.500000   6307.000000   6307.500000   6308.000000
# 25%     6332.500000   6333.000000   6333.500000   6334.000000   6334.500000
# 50%     6342.000000   6342.500000   6343.000000   6343.500000   6344.000000
# 75%     6351.000000   6351.500000   6352.000000   6352.500000   6353.000000
# max     6387.500000   6388.000000   6388.500000   6389.000000   6389.500000
#
#            ...       spreed_vol_2  spreed_vol_3  spreed_vol_4  spreed_vol_5  \
# count      ...       5.184300e+04  5.184300e+04  5.184300e+04  5.184300e+04
# mean       ...      -6.106484e+04 -9.892336e+04 -1.397470e+05 -6.761152e+04
# std        ...       6.121657e+05  5.393544e+05  5.744475e+05  5.126681e+05
# min        ...      -5.753231e+06 -6.036137e+06 -8.231299e+06 -5.793715e+06
# 25%        ...      -2.618195e+05 -3.192965e+05 -3.405250e+05 -3.097930e+05
# 50%        ...      -2.392000e+03 -6.742300e+04 -3.022300e+04 -6.725900e+04
# 75%        ...       2.183940e+05  1.568715e+05  1.604230e+05  1.402095e+05
# max        ...       6.578068e+06  5.498410e+06  4.318003e+06  5.527238e+06
#
#        spreed_vol_6  spreed_vol_7  spreed_vol_8  spreed_vol_9  \
# count  5.184300e+04  5.184300e+04  5.184300e+04  5.184300e+04
# mean  -6.522150e+04 -8.426815e+04 -7.777664e+04 -1.111580e+05
# std    5.910704e+05  5.521310e+05  6.069256e+05  6.218410e+05
# min   -5.502527e+06 -3.893899e+06 -4.065793e+06 -7.065249e+06
# 25%   -3.277400e+05 -3.892820e+05 -3.455635e+05 -4.060555e+05
# 50%   -4.801100e+04 -1.195740e+05 -3.661100e+04 -8.624500e+04
# 75%    1.594815e+05  1.667785e+05  2.702600e+05  2.195585e+05
# max    4.851137e+06  4.873956e+06  3.984442e+06  3.932017e+06
#
#        accum_spreed_vol             y
# count      5.184300e+04  51843.000000
# mean      -1.155567e+06      0.000829
# std        3.170800e+06      0.147309
# min       -2.079070e+07     -1.000000
# 25%       -3.264094e+06      0.000000
# 50%       -1.251082e+06      0.000000
# 75%        1.032906e+06      0.000000
# max        1.673460e+07      1.000000
#
# [8 rows x 111 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(['y'], axis=1), df['y'], test_size=0.7, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_squared_error

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import SelectPercentile, f_classif

import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import metrics   #Additional     scklearn functions

import matplotlib.pyplot as plt

ind_params = {'n_estimators': 100, 'seed':0, 'colsample_bytree': 0.8,
              'objective': 'multi:softmax', 'min_child_weight': 3, 'max_depth': 7,
             'subsample': 0.9, 'learning_rate': 0.1}

# clf = XGBClassifier(learning_rate =0.01, n_estimators=2000, max_depth=6,
#  min_child_weight=1, max_delta_step = 5, gamma=0, subsample=0.85, colsample_bytree=0.8,
#  objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27, reg_alpha= 0.01)
clf = XGBClassifier(**ind_params)
clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)
# Out:
# [0]	validation_0-merror:0.013182	validation_1-merror:0.01736
# [1]	validation_0-merror:0.012796	validation_1-merror:0.016946
# [2]	validation_0-merror:0.012153	validation_1-merror:0.01623
# [3]	validation_0-merror:0.011445	validation_1-merror:0.015817
# [4]	validation_0-merror:0.01151	validation_1-merror:0.015899
# [5]	validation_0-merror:0.011253	validation_1-merror:0.015817
# [6]	validation_0-merror:0.011381	validation_1-merror:0.015706
# [7]	validation_0-merror:0.011381	validation_1-merror:0.015403
# [8]	validation_0-merror:0.011381	validation_1-merror:0.015403
# [9]	validation_0-merror:0.010867	validation_1-merror:0.015376
# [10]	validation_0-merror:0.010995	validation_1-merror:0.015265
# [11]	validation_0-merror:0.010738	validation_1-merror:0.01499
# [12]	validation_0-merror:0.010995	validation_1-merror:0.015073
# [13]	validation_0-merror:0.010545	validation_1-merror:0.015265
# [14]	validation_0-merror:0.010545	validation_1-merror:0.014935
# [15]	validation_0-merror:0.010224	validation_1-merror:0.014825
# [16]	validation_0-merror:0.010159	validation_1-merror:0.014852
# [17]	validation_0-merror:0.010031	validation_1-merror:0.014714
# [18]	validation_0-merror:0.009967	validation_1-merror:0.014577
# [19]	validation_0-merror:0.009452	validation_1-merror:0.014604
# [20]	validation_0-merror:0.009324	validation_1-merror:0.014549
# [21]	validation_0-merror:0.009066	validation_1-merror:0.014632
# [22]	validation_0-merror:0.008745	validation_1-merror:0.014659
# [23]	validation_0-merror:0.008359	validation_1-merror:0.014687
# [24]	validation_0-merror:0.008295	validation_1-merror:0.014714
# [25]	validation_0-merror:0.008102	validation_1-merror:0.014632
# [26]	validation_0-merror:0.007716	validation_1-merror:0.014687
# [27]	validation_0-merror:0.00778	validation_1-merror:0.014742
# [28]	validation_0-merror:0.007395	validation_1-merror:0.01488
# [29]	validation_0-merror:0.007266	validation_1-merror:0.014825
# [30]	validation_0-merror:0.007009	validation_1-merror:0.014797
# [31]	validation_0-merror:0.00643	validation_1-merror:0.014797
# [32]	validation_0-merror:0.006366	validation_1-merror:0.014714
# [33]	validation_0-merror:0.006044	validation_1-merror:0.014742
# [34]	validation_0-merror:0.006109	validation_1-merror:0.01477
# [35]	validation_0-merror:0.005723	validation_1-merror:0.014742
# [36]	validation_0-merror:0.005466	validation_1-merror:0.014907
# [37]	validation_0-merror:0.005337	validation_1-merror:0.014825
# [38]	validation_0-merror:0.005208	validation_1-merror:0.014797
# [39]	validation_0-merror:0.00508	validation_1-merror:0.014742
# [40]	validation_0-merror:0.005144	validation_1-merror:0.014742
# [41]	validation_0-merror:0.004758	validation_1-merror:0.014825
# [42]	validation_0-merror:0.004565	validation_1-merror:0.014742
# [43]	validation_0-merror:0.004437	validation_1-merror:0.01477
# [44]	validation_0-merror:0.004244	validation_1-merror:0.014825
# [45]	validation_0-merror:0.003794	validation_1-merror:0.01477
# [46]	validation_0-merror:0.003601	validation_1-merror:0.014714
# [47]	validation_0-merror:0.003408	validation_1-merror:0.014687
# [48]	validation_0-merror:0.003279	validation_1-merror:0.014714
# [49]	validation_0-merror:0.003279	validation_1-merror:0.014714
# [50]	validation_0-merror:0.003151	validation_1-merror:0.014714
# [51]	validation_0-merror:0.002894	validation_1-merror:0.014797
# [52]	validation_0-merror:0.002636	validation_1-merror:0.014632
# [53]	validation_0-merror:0.002443	validation_1-merror:0.014714
# [54]	validation_0-merror:0.002315	validation_1-merror:0.01477
# [55]	validation_0-merror:0.002251	validation_1-merror:0.014714
# [56]	validation_0-merror:0.002058	validation_1-merror:0.014825
# [57]	validation_0-merror:0.001993	validation_1-merror:0.014825
# [58]	validation_0-merror:0.0018	validation_1-merror:0.014825
# [59]	validation_0-merror:0.0018	validation_1-merror:0.014825
# [60]	validation_0-merror:0.001736	validation_1-merror:0.014852
# [61]	validation_0-merror:0.001672	validation_1-merror:0.014742
# [62]	validation_0-merror:0.001479	validation_1-merror:0.01477
# [63]	validation_0-merror:0.001543	validation_1-merror:0.014714
# [64]	validation_0-merror:0.001415	validation_1-merror:0.01477
# [65]	validation_0-merror:0.00135	validation_1-merror:0.014825
# [66]	validation_0-merror:0.00135	validation_1-merror:0.014825
# [67]	validation_0-merror:0.00135	validation_1-merror:0.014742
# [68]	validation_0-merror:0.001286	validation_1-merror:0.014797
# [69]	validation_0-merror:0.001222	validation_1-merror:0.014797
# [70]	validation_0-merror:0.001093	validation_1-merror:0.014687
# [71]	validation_0-merror:0.0009	validation_1-merror:0.014742
# [72]	validation_0-merror:0.000836	validation_1-merror:0.014742
# [73]	validation_0-merror:0.000772	validation_1-merror:0.014714
# [74]	validation_0-merror:0.000643	validation_1-merror:0.014714
# [75]	validation_0-merror:0.000707	validation_1-merror:0.014714
# [76]	validation_0-merror:0.000579	validation_1-merror:0.014687
# [77]	validation_0-merror:0.000579	validation_1-merror:0.014659
# [78]	validation_0-merror:0.000579	validation_1-merror:0.014687
# [79]	validation_0-merror:0.00045	validation_1-merror:0.014632
# [80]	validation_0-merror:0.00045	validation_1-merror:0.014604
# [81]	validation_0-merror:0.00045	validation_1-merror:0.014687
# [82]	validation_0-merror:0.00045	validation_1-merror:0.014687
# [83]	validation_0-merror:0.00045	validation_1-merror:0.014549
# [84]	validation_0-merror:0.000386	validation_1-merror:0.014604
# [85]	validation_0-merror:0.000386	validation_1-merror:0.014466
# [86]	validation_0-merror:0.000386	validation_1-merror:0.014549
# [87]	validation_0-merror:0.000386	validation_1-merror:0.014577
# [88]	validation_0-merror:0.000322	validation_1-merror:0.014549
# [89]	validation_0-merror:0.000386	validation_1-merror:0.014577
# [90]	validation_0-merror:0.000257	validation_1-merror:0.014659
# [91]	validation_0-merror:0.000257	validation_1-merror:0.014632
# [92]	validation_0-merror:0.000257	validation_1-merror:0.014604
# [93]	validation_0-merror:0.000257	validation_1-merror:0.014632
# [94]	validation_0-merror:0.000193	validation_1-merror:0.014742
# [95]	validation_0-merror:0.000193	validation_1-merror:0.014659
# [96]	validation_0-merror:0.000193	validation_1-merror:0.014604
# [97]	validation_0-merror:0.000193	validation_1-merror:0.014549
# [98]	validation_0-merror:0.000193	validation_1-merror:0.014549
# [99]	validation_0-merror:0.000193	validation_1-merror:0.014604
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=7, min_child_weight=3, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='multi:softprob', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=0, silent=True,
#        subsample=0.9)

# %%
from sklearn.metrics import f1_score
y_pred = clf.predict(X_test)

# %%
def feature_importance(df, clf):
    columns = [x for x in df.columns.tolist() if x != 'y']
    t = zip(columns, clf.feature_importances_.tolist())
    nonzero_feature_cnt = 0
    fi = sorted(t, key=lambda tup: tup[1], reverse=True)
    for i in fi:
        print(i)
        if i[1] > 0:
            nonzero_feature_cnt += 1
    print("non zero feature cnt: {0}, feature total cnt:{1}".format(nonzero_feature_cnt, len(clf.feature_importances_)))
    return fi

# %%
feature_importance(df, clf)
# Out:
# ('ask_vol_0', 0.07074712216854095)
# ('bid_vol_0', 0.06455209851264954)
# ('spreed_vol_1', 0.05067525804042816)
# ('bid_vol_1', 0.04187833145260811)
# ('spreed_vol_0', 0.04051542654633522)
# ('ask_vol_1', 0.03915252164006233)
# ('ask_vol_mean', 0.03568331152200699)
# ('bid_vol_3', 0.034196507185697556)
# ('ask_vol_2', 0.031346797943115234)
# ('ask_vol_4', 0.029612191021442413)
# ('bid_vol_2', 0.02948829159140587)
# ('accum_spreed_vol', 0.029364390298724174)
# ('bid_vol_5', 0.028868788853287697)
# ('bid_vol_mean', 0.02837318740785122)
# ('ask_vol_3', 0.02787758596241474)
# ('spreed_vol_4', 0.027381984516978264)
# ('ask_vol_8', 0.02725808508694172)
# ('bid_vol_6', 0.02614298090338707)
# ('bid_vol_8', 0.02614298090338707)
# ('ask_vol_5', 0.02391277439892292)
# ('bid_vol_7', 0.023169372230768204)
# ('bid_vol_4', 0.02279767021536827)
# ('bid_vol_9', 0.02217816933989525)
# ('spreed_vol_2', 0.022054268047213554)
# ('ask_vol_7', 0.021558666601777077)
# ('ask_vol_6', 0.0210630651563406)
# ('spreed_vol_3', 0.01970016025006771)
# ('spreed_vol_7', 0.019576260820031166)
# ('ask_p_0', 0.019204558804631233)
# ('ask_vol_9', 0.018956758081912994)
# ('spreed_vol_9', 0.01883285865187645)
# ('spreed_vol_5', 0.0177177544683218)
# ('spreed_vol_8', 0.017346054315567017)
# ('spreed_vol_6', 0.016974352300167084)
# ('ask_p_1', 0.003840911900624633)
# ('ask_p_2', 0.0007434022845700383)
# ('spreed_5', 0.0004956015618517995)
# ('ask_p_3', 0.00012390039046294987)
# ('bid_p_0', 0.00012390039046294987)
# ('spreed_6', 0.00012390039046294987)
# ('spreed_7', 0.00012390039046294987)
# ('accum_spreed', 0.00012390039046294987)
# ('ask_p_4', 0.0)
# ('ask_p_5', 0.0)
# ('ask_p_6', 0.0)
# ('ask_p_7', 0.0)
# ('ask_p_8', 0.0)
# ('ask_p_9', 0.0)
# ('bid_p_1', 0.0)
# ('bid_p_2', 0.0)
# ('bid_p_3', 0.0)
# ('bid_p_4', 0.0)
# ('bid_p_5', 0.0)
# ('bid_p_6', 0.0)
# ('bid_p_7', 0.0)
# ('bid_p_8', 0.0)
# ('bid_p_9', 0.0)
# ('spreed_0', 0.0)
# ('mid_p0', 0.0)
# ('spreed_1', 0.0)
# ('mid_p1', 0.0)
# ('spreed_2', 0.0)
# ('mid_p2', 0.0)
# ('spreed_3', 0.0)
# ('mid_p3', 0.0)
# ('spreed_4', 0.0)
# ('mid_p4', 0.0)
# ('mid_p5', 0.0)
# ('mid_p6', 0.0)
# ('mid_p7', 0.0)
# ('spreed_8', 0.0)
# ('mid_p8', 0.0)
# ('spreed_9', 0.0)
# ('mid_p9', 0.0)
# ('ask_p_diff_1_0', 0.0)
# ('bid_p_diff_1_0', 0.0)
# ('ask_p_diff_2_0', 0.0)
# ('bid_p_diff_2_0', 0.0)
# ('ask_p_diff_2_1', 0.0)
# ('bid_p_diff_2_1', 0.0)
# ('ask_p_diff_3_0', 0.0)
# ('bid_p_diff_3_0', 0.0)
# ('ask_p_diff_3_2', 0.0)
# ('bid_p_diff_3_2', 0.0)
# ('ask_p_diff_4_0', 0.0)
# ('bid_p_diff_4_0', 0.0)
# ('ask_p_diff_4_3', 0.0)
# ('bid_p_diff_4_3', 0.0)
# ('ask_p_diff_5_0', 0.0)
# ('bid_p_diff_5_0', 0.0)
# ('ask_p_diff_5_4', 0.0)
# ('bid_p_diff_5_4', 0.0)
# ('ask_p_diff_6_0', 0.0)
# ('bid_p_diff_6_0', 0.0)
# ('ask_p_diff_6_5', 0.0)
# ('bid_p_diff_6_5', 0.0)
# ('ask_p_diff_7_0', 0.0)
# ('bid_p_diff_7_0', 0.0)
# ('ask_p_diff_7_6', 0.0)
# ('bid_p_diff_7_6', 0.0)
# ('ask_p_diff_8_0', 0.0)
# ('bid_p_diff_8_0', 0.0)
# ('ask_p_diff_8_7', 0.0)
# ('bid_p_diff_8_7', 0.0)
# ('ask_p_diff_9_0', 0.0)
# ('bid_p_diff_9_0', 0.0)
# ('ask_p_diff_9_8', 0.0)
# ('bid_p_diff_9_8', 0.0)
# ('ask_p_mean', 0.0)
# ('bid_mean', 0.0)
# non zero feature cnt: 42, feature total cnt:110
# [('ask_vol_0', 0.07074712216854095),
#  ('bid_vol_0', 0.06455209851264954),
#  ('spreed_vol_1', 0.05067525804042816),
#  ('bid_vol_1', 0.04187833145260811),
#  ('spreed_vol_0', 0.04051542654633522),
#  ('ask_vol_1', 0.03915252164006233),
#  ('ask_vol_mean', 0.03568331152200699),
#  ('bid_vol_3', 0.034196507185697556),
#  ('ask_vol_2', 0.031346797943115234),
#  ('ask_vol_4', 0.029612191021442413),
#  ('bid_vol_2', 0.02948829159140587),
#  ('accum_spreed_vol', 0.029364390298724174),
#  ('bid_vol_5', 0.028868788853287697),
#  ('bid_vol_mean', 0.02837318740785122),
#  ('ask_vol_3', 0.02787758596241474),
#  ('spreed_vol_4', 0.027381984516978264),
#  ('ask_vol_8', 0.02725808508694172),
#  ('bid_vol_6', 0.02614298090338707),
#  ('bid_vol_8', 0.02614298090338707),
#  ('ask_vol_5', 0.02391277439892292),
#  ('bid_vol_7', 0.023169372230768204),
#  ('bid_vol_4', 0.02279767021536827),
#  ('bid_vol_9', 0.02217816933989525),
#  ('spreed_vol_2', 0.022054268047213554),
#  ('ask_vol_7', 0.021558666601777077),
#  ('ask_vol_6', 0.0210630651563406),
#  ('spreed_vol_3', 0.01970016025006771),
#  ('spreed_vol_7', 0.019576260820031166),
#  ('ask_p_0', 0.019204558804631233),
#  ('ask_vol_9', 0.018956758081912994),
#  ('spreed_vol_9', 0.01883285865187645),
#  ('spreed_vol_5', 0.0177177544683218),
#  ('spreed_vol_8', 0.017346054315567017),
#  ('spreed_vol_6', 0.016974352300167084),
#  ('ask_p_1', 0.003840911900624633),
#  ('ask_p_2', 0.0007434022845700383),
#  ('spreed_5', 0.0004956015618517995),
#  ('ask_p_3', 0.00012390039046294987),
#  ('bid_p_0', 0.00012390039046294987),
#  ('spreed_6', 0.00012390039046294987),
#  ('spreed_7', 0.00012390039046294987),
#  ('accum_spreed', 0.00012390039046294987),
#  ('ask_p_4', 0.0),
#  ('ask_p_5', 0.0),
#  ('ask_p_6', 0.0),
#  ('ask_p_7', 0.0),
#  ('ask_p_8', 0.0),
#  ('ask_p_9', 0.0),
#  ('bid_p_1', 0.0),
#  ('bid_p_2', 0.0),
#  ('bid_p_3', 0.0),
#  ('bid_p_4', 0.0),
#  ('bid_p_5', 0.0),
#  ('bid_p_6', 0.0),
#  ('bid_p_7', 0.0),
#  ('bid_p_8', 0.0),
#  ('bid_p_9', 0.0),
#  ('spreed_0', 0.0),
#  ('mid_p0', 0.0),
#  ('spreed_1', 0.0),
#  ('mid_p1', 0.0),
#  ('spreed_2', 0.0),
#  ('mid_p2', 0.0),
#  ('spreed_3', 0.0),
#  ('mid_p3', 0.0),
#  ('spreed_4', 0.0),
#  ('mid_p4', 0.0),
#  ('mid_p5', 0.0),
#  ('mid_p6', 0.0),
#  ('mid_p7', 0.0),
#  ('spreed_8', 0.0),
#  ('mid_p8', 0.0),
#  ('spreed_9', 0.0),
#  ('mid_p9', 0.0),
#  ('ask_p_diff_1_0', 0.0),
#  ('bid_p_diff_1_0', 0.0),
#  ('ask_p_diff_2_0', 0.0),
#  ('bid_p_diff_2_0', 0.0),
#  ('ask_p_diff_2_1', 0.0),
#  ('bid_p_diff_2_1', 0.0),
#  ('ask_p_diff_3_0', 0.0),
#  ('bid_p_diff_3_0', 0.0),
#  ('ask_p_diff_3_2', 0.0),
#  ('bid_p_diff_3_2', 0.0),
#  ('ask_p_diff_4_0', 0.0),
#  ('bid_p_diff_4_0', 0.0),
#  ('ask_p_diff_4_3', 0.0),
#  ('bid_p_diff_4_3', 0.0),
#  ('ask_p_diff_5_0', 0.0),
#  ('bid_p_diff_5_0', 0.0),
#  ('ask_p_diff_5_4', 0.0),
#  ('bid_p_diff_5_4', 0.0),
#  ('ask_p_diff_6_0', 0.0),
#  ('bid_p_diff_6_0', 0.0),
#  ('ask_p_diff_6_5', 0.0),
#  ('bid_p_diff_6_5', 0.0),
#  ('ask_p_diff_7_0', 0.0),
#  ('bid_p_diff_7_0', 0.0),
#  ('ask_p_diff_7_6', 0.0),
#  ('bid_p_diff_7_6', 0.0),
#  ('ask_p_diff_8_0', 0.0),
#  ('bid_p_diff_8_0', 0.0),
#  ('ask_p_diff_8_7', 0.0),
#  ('bid_p_diff_8_7', 0.0),
#  ('ask_p_diff_9_0', 0.0),
#  ('bid_p_diff_9_0', 0.0),
#  ('ask_p_diff_9_8', 0.0),
#  ('bid_p_diff_9_8', 0.0),
#  ('ask_p_mean', 0.0),
#  ('bid_mean', 0.0)]

# %%
f1_score(y_test, y_pred, average='macro')
# Out:
# 0.6826923433275575

# %%
report = metrics.classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.81      0.40      0.54       378
#            0       0.99      1.00      0.99     35533
#            1       0.69      0.42      0.52       380
#
#    micro avg       0.99      0.99      0.99     36291
#    macro avg       0.83      0.61      0.68     36291
# weighted avg       0.98      0.99      0.98     36291

# %%
from matplotlib import pyplot
import scikitplot as skplt

skplt.plotters.plot_feature_importances(clf, feature_names=df.columns, figsize=(11.7, 8.27))
plt.show()
# Out:
# /Users/magiclane/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function plot_feature_importances is deprecated; This will be removed in v0.4.0. Please use scikitplot.estimators.plot_feature_importances instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
X = df.drop(['y'], axis=1)
y = df['y']
predict = clf.predict(X)
report = metrics.classification_report(y, predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.90      0.58      0.70       541
#            0       0.99      1.00      1.00     50718
#            1       0.83      0.62      0.71       584
#
#    micro avg       0.99      0.99      0.99     51843
#    macro avg       0.91      0.73      0.80     51843
# weighted avg       0.99      0.99      0.99     51843

# %%
df['predict'] = predict

# %%
def profit_long(df, amount=1000):
    long, short = None, None
    xbt = None
    profit = 0
    for index, row in df.iterrows():
        descision = row['predict']
        best_bid = row['bid_p_0']
        best_ask = row['ask_p_0']
        if descision == 1:
            if long is None:
                long = best_ask
                xbt = amount / long
                print('long: price-{0}, vol-{1}'.format(long, row['ask_vol_0']))
        elif descision == -1:
            if long is not None:
                tmp = xbt * best_bid
                profit += (tmp - amount)
                amount = tmp
                print('sell long: price-{0}, vol-{1}, profit: {2}'.format(best_bid, row['bid_vol_0'], profit))
                long = None
    print("net return: {0}".format(profit))
    
def profit_short(df, amount=1000):
    short = None
    xbt = None
    profit = 0
    for index, row in df.iterrows():
        descision = row['predict']
        best_bid = row['bid_p_0']
        best_ask = row['ask_p_0']
        if descision == 1:
            if short is not None:
                tmp = sxbt * best_ask
                profit += (amount - tmp)
                amount = tmp
                print('sell short: price-{0}, vol-{1}, profit: {2}'.format(best_ask, row['ask_vol_0'], profit))
                short = None
        elif descision == -1:
            if short is None:
                short = best_bid
                sxbt = amount / short
                print('short: price-{0}, vol-{1}'.format(short, row['bid_vol_0']))
    print("net return: {0}".format(profit))

# %%
X3 = df3.drop(['y'], axis=1)
y3 = df3['y']
predict3 = clf.predict(X3)
report3 = metrics.classification_report(y3, predict3)
print(report3)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.93      0.53      0.67       118
#            0       0.99      1.00      1.00     17015
#            1       0.88      0.56      0.69       147
#
#    micro avg       0.99      0.99      0.99     17280
#    macro avg       0.93      0.70      0.79     17280
# weighted avg       0.99      0.99      0.99     17280

# %%
profit_long(df, 500)
# Out:
# long: price-6307.5, vol-90503.0
# sell long: price-6306.5, vol-200726.0, profit: -0.0792707094728371
# long: price-6304.0, vol-220937.0
# sell long: price-6309.0, vol-383131.0, profit: 0.31724002124610706
# long: price-6305.0, vol-378880.0
# sell long: price-6319.0, vol-215778.0, profit: 1.4281744162179848
# long: price-6319.0, vol-142505.0
# sell long: price-6323.0, vol-138269.0, profit: 1.7455842433528233
# long: price-6318.0, vol-8471.0
# sell long: price-6316.5, vol-338527.0, profit: 1.6264613601041447
# long: price-6317.0, vol-58536.0
# sell long: price-6334.5, vol-343714.0, profit: 3.016118329203721
# long: price-6340.0, vol-3438029.0
# sell long: price-6338.5, vol-112160.0, profit: 2.8971082065706355
# long: price-6335.0, vol-119967.0
# sell long: price-6334.0, vol-49262.0, profit: 2.817724290515912
# long: price-6330.5, vol-603751.0
# sell long: price-6334.0, vol-89430.0, profit: 3.095721610635451
# long: price-6333.5, vol-452412.0
# sell long: price-6335.5, vol-61671.0, profit: 3.2545897630348577
# long: price-6331.5, vol-422667.0
# sell long: price-6348.5, vol-526716.0, profit: 4.605822176518416
# long: price-6359.5, vol-26419.0
# sell long: price-6364.0, vol-30000.0, profit: 4.962882668663099
# long: price-6354.5, vol-1032.0
# sell long: price-6353.5, vol-64116.0, profit: 4.883417268919857
# long: price-6350.5, vol-237991.0
# sell long: price-6349.0, vol-95138.0, profit: 4.764162859675935
# long: price-6336.0, vol-826410.0
# sell long: price-6342.0, vol-148718.0, profit: 5.242159226020306
# long: price-6338.5, vol-92883.0
# sell long: price-6338.0, vol-54502.0, profit: 5.20230420044436
# long: price-6335.0, vol-424751.0
# sell long: price-6343.5, vol-417131.0, profit: 5.8801604886375
# long: price-6340.0, vol-107912.0
# sell long: price-6340.0, vol-197642.0, profit: 5.8801604886375
# long: price-6337.0, vol-106921.0
# sell long: price-6352.5, vol-40191.0, profit: 7.117519252654176
# long: price-6348.0, vol-284048.0
# sell long: price-6346.5, vol-184935.0, profit: 6.997689971167233
# long: price-6347.5, vol-111486.0
# sell long: price-6355.5, vol-442.0, profit: 7.636678788775669
# long: price-6352.5, vol-415604.0
# sell long: price-6352.0, vol-128036.0, profit: 7.596723127320388
# long: price-6348.5, vol-701643.0
# sell long: price-6354.0, vol-465076.0, profit: 8.036477711426869
# long: price-6357.0, vol-38807.0
# sell long: price-6361.5, vol-162474.0, profit: 8.396107119905935
# long: price-6357.5, vol-44538.0
# sell long: price-6380.0, vol-451067.0, profit: 10.195385517105706
# long: price-6378.0, vol-512208.0
# sell long: price-6375.5, vol-80842.0, profit: 9.995403004751836
# long: price-6377.0, vol-41134.0
# sell long: price-6376.5, vol-32427.0, profit: 9.955415910271256
# long: price-6375.5, vol-224185.0
# sell long: price-6374.5, vol-5422.0, profit: 9.875429177323156
# long: price-6372.5, vol-164506.0
# sell long: price-6369.0, vol-302084.0, profit: 9.59538774897942
# long: price-6370.0, vol-97659.0
# sell long: price-6370.0, vol-371965.0, profit: 9.595387748979476
# long: price-6370.0, vol-761318.0
# sell long: price-6368.0, vol-496429.0, profit: 9.435389197095958
# long: price-6369.0, vol-243603.0
# sell long: price-6371.5, vol-60807.0, profit: 9.635355985130673
# long: price-6366.5, vol-3686.0
# sell long: price-6366.0, vol-553976.0, profit: 9.595331218305489
# long: price-6363.5, vol-50642.0
# sell long: price-6365.0, vol-43350.0, profit: 9.715452691838493
# long: price-6353.0, vol-110940.0
# sell long: price-6359.0, vol-45422.0, profit: 10.196846162033808
# long: price-6355.5, vol-25.0
# sell long: price-6355.0, vol-184812.0, profit: 10.156707947403845
# long: price-6346.5, vol-112438.0
# sell long: price-6352.0, vol-490131.0, profit: 10.598819645774768
# long: price-6343.0, vol-95159.0
# sell long: price-6339.0, vol-73111.0, profit: 10.27682764221447
# long: price-6344.0, vol-301309.0
# sell long: price-6344.5, vol-437027.0, profit: 10.317044920559567
# long: price-6342.0, vol-148869.0
# sell long: price-6358.5, vol-196522.0, profit: 11.644738273001849
# long: price-6356.0, vol-137862.0
# sell long: price-6363.5, vol-311947.0, profit: 12.24847262433093
# long: price-6356.0, vol-137078.0
# sell long: price-6358.5, vol-80387.0, profit: 12.449954874419177
# long: price-6357.0, vol-175377.0
# sell long: price-6373.0, vol-199228.0, profit: 13.739745542657488
# long: price-6370.0, vol-658528.0
# sell long: price-6370.5, vol-109664.0, profit: 13.78007048343784
# long: price-6362.0, vol-207471.0
# sell long: price-6360.5, vol-128590.0, profit: 13.658934031736294
# long: price-6357.5, vol-51675.0
# sell long: price-6361.0, vol-487601.0, profit: 13.941719131085279
# long: price-6353.5, vol-108774.0
# sell long: price-6355.5, vol-279935.0, profit: 14.103501367374292
# long: price-6351.5, vol-112843.0
# sell long: price-6355.5, vol-281167.0, profit: 14.4272696119574
# long: price-6353.0, vol-166550.0
# sell long: price-6354.5, vol-598051.0, profit: 14.548730481533653
# long: price-6346.0, vol-538242.0
# sell long: price-6342.5, vol-4909.0, profit: 14.264942180763796
# long: price-6343.5, vol-124879.0
# sell long: price-6345.5, vol-139813.0, profit: 14.427081360138232
# long: price-6344.5, vol-252940.0
# sell long: price-6350.0, vol-8024.0, profit: 14.873034382043897
# long: price-6348.5, vol-811679.0
# sell long: price-6347.0, vol-73330.0, profit: 14.75138209385409
# long: price-6343.5, vol-98486.0
# sell long: price-6347.0, vol-158711.0, profit: 15.035394048977992
# long: price-6339.5, vol-218267.0
# sell long: price-6341.5, vol-534402.0, profit: 15.197878596355167
# long: price-6340.0, vol-178189.0
# sell long: price-6345.5, vol-143876.0, profit: 15.644816819112293
# long: price-6338.5, vol-192295.0
# sell long: price-6333.5, vol-93522.0, profit: 15.238060633248892
# long: price-6332.0, vol-111109.0
# sell long: price-6331.0, vol-570470.0, profit: 15.156690124620695
# long: price-6328.0, vol-460153.0
# sell long: price-6326.0, vol-96455.0, profit: 14.993871954543351
# long: price-6317.0, vol-152558.0
# sell long: price-6321.5, vol-591986.0, profit: 15.360734772937462
# long: price-6319.5, vol-50905.0
# sell long: price-6324.0, vol-113613.0, profit: 15.727713696345631
# long: price-6324.5, vol-82171.0
# sell long: price-6336.5, vol-10212.0, profit: 16.706246792140746
# long: price-6336.0, vol-159758.0
# sell long: price-6335.0, vol-33278.0, profit: 16.62469593248295
# long: price-6334.0, vol-63174.0
# sell long: price-6334.0, vol-65365.0, profit: 16.62469593248295
# long: price-6331.0, vol-184858.0
# sell long: price-6332.5, vol-158602.0, profit: 16.74709950915303
# long: price-6324.0, vol-200627.0
# sell long: price-6328.0, vol-27038.0, profit: 17.073947769437154
# long: price-6323.5, vol-58293.0
# sell long: price-6333.0, vol-300090.0, profit: 17.850764801746777
# long: price-6334.0, vol-207140.0
# sell long: price-6333.0, vol-19747.0, profit: 17.76900749754691
# long: price-6331.0, vol-42414.0
# sell long: price-6331.0, vol-366302.0, profit: 17.76900749754691
# long: price-6331.5, vol-868978.0
# sell long: price-6342.5, vol-454765.0, profit: 18.66855090471313
# long: price-6339.0, vol-219836.0
# sell long: price-6337.5, vol-53656.0, profit: 18.545818166685535
# long: price-6323.5, vol-80391.0
# sell long: price-6334.5, vol-234294.0, profit: 19.44785090169512
# long: price-6330.5, vol-113278.0
# sell long: price-6337.5, vol-71758.0, profit: 20.022234434798634
# long: price-6337.0, vol-219778.0
# sell long: price-6351.5, vol-49630.0, profit: 21.212122773019246
# long: price-6348.5, vol-349684.0
# sell long: price-6347.0, vol-12359.0, profit: 21.088972708569486
# long: price-6341.5, vol-202134.0
# sell long: price-6336.5, vol-55893.0, profit: 20.678116465796847
# long: price-6337.0, vol-14256.0
# sell long: price-6341.5, vol-33272.0, profit: 21.047857908766105
# long: price-6340.5, vol-544518.0
# sell long: price-6339.0, vol-192869.0, profit: 20.924591323029404
# long: price-6339.5, vol-299802.0
# sell long: price-6343.0, vol-154342.0, profit: 21.212190671500252
# net return: 21.212190671500252

# %%
profit_short(df, 500)
# Out:
# short: price-6306.5, vol-200726.0
# sell short: price-6304.0, vol-220937.0, profit: 0.1982081978910628
# short: price-6309.0, vol-383131.0
# sell short: price-6305.0, vol-378880.0, profit: 0.515089980615528
# short: price-6319.0, vol-215778.0
# sell short: price-6319.0, vol-142505.0, profit: 0.515089980615528
# short: price-6323.0, vol-138269.0
# sell short: price-6318.0, vol-8471.0, profit: 0.9100646050180217
# short: price-6316.5, vol-338527.0
# sell short: price-6317.0, vol-58536.0, profit: 0.8705577629856407
# short: price-6334.5, vol-343714.0
# sell short: price-6340.0, vol-3438029.0, profit: 0.4371830795372489
# short: price-6338.5, vol-112160.0
# sell short: price-6335.0, vol-119967.0, profit: 0.7130322329996943
# short: price-6334.0, vol-49262.0
# sell short: price-6330.5, vol-603751.0, profit: 0.9889249370073117
# short: price-6334.0, vol-89430.0
# sell short: price-6333.5, vol-452412.0, profit: 1.0283164017264994
# short: price-6335.5, vol-61671.0
# sell short: price-6331.5, vol-422667.0, profit: 1.3433486382339765
# short: price-6348.5, vol-526716.0
# sell short: price-6359.5, vol-26419.0, profit: 0.4793298676614768
# short: price-6364.0, vol-30000.0
# sell short: price-6354.5, vol-1032.0, profit: 1.2250002583367063
# short: price-6353.5, vol-64116.0
# sell short: price-6350.5, vol-237991.0, profit: 1.460512180777073
# short: price-6349.0, vol-95138.0
# sell short: price-6336.0, vol-826410.0, profit: 2.48130495785216
# short: price-6342.0, vol-148718.0
# sell short: price-6338.5, vol-92883.0, profit: 2.755873774100621
# short: price-6338.0, vol-54502.0
# sell short: price-6335.0, vol-424751.0, profit: 2.99123703990648
# short: price-6343.5, vol-417131.0
# sell short: price-6340.0, vol-107912.0, profit: 3.2654595779943065
# short: price-6340.0, vol-197642.0
# sell short: price-6337.0, vol-106921.0, profit: 3.5005074677839048
# short: price-6352.5, vol-40191.0
# sell short: price-6348.0, vol-284048.0, profit: 3.8522190327418
# short: price-6346.5, vol-184935.0
# sell short: price-6347.5, vol-111486.0, profit: 3.7740424344644907
# short: price-6355.5, vol-442.0
# sell short: price-6352.5, vol-415604.0, profit: 4.008277014386863
# short: price-6352.0, vol-128036.0
# sell short: price-6348.5, vol-701643.0, profit: 4.281572201800259
# short: price-6354.0, vol-465076.0
# sell short: price-6357.0, vol-38807.0, profit: 4.047521952603745
# short: price-6361.5, vol-162474.0
# sell short: price-6357.5, vol-44538.0, profit: 4.359368201474183
# short: price-6380.0, vol-451067.0
# sell short: price-6378.0, vol-512208.0, profit: 4.514741440282535
# short: price-6375.5, vol-80842.0
# sell short: price-6377.0, vol-41134.0, profit: 4.398165816748758
# short: price-6376.5, vol-32427.0
# sell short: price-6375.5, vol-224185.0, profit: 4.475888993128137
# short: price-6374.5, vol-5422.0
# sell short: price-6372.5, vol-164506.0, profit: 4.631359731541181
# short: price-6369.0, vol-302084.0
# sell short: price-6370.0, vol-97659.0, profit: 4.553581643887185
# short: price-6370.0, vol-371965.0
# sell short: price-6370.0, vol-761318.0, profit: 4.553581643887185
# short: price-6368.0, vol-496429.0
# sell short: price-6369.0, vol-243603.0, profit: 4.475779128441786
# short: price-6371.5, vol-60807.0
# sell short: price-6366.5, vol-3686.0, profit: 4.864639067915618
# short: price-6366.0, vol-553976.0
# sell short: price-6363.5, vol-50642.0, profit: 5.059084308620925
# short: price-6365.0, vol-43350.0
# sell short: price-6353.0, vol-110940.0, profit: 5.992201510238658
# short: price-6359.0, vol-45422.0
# sell short: price-6355.5, vol-25.0, profit: 6.2641038997203395
# short: price-6355.0, vol-184812.0
# sell short: price-6346.5, vol-112438.0, profit: 6.924490228099955
# short: price-6352.0, vol-490131.0
# sell short: price-6343.0, vol-95159.0, profit: 7.623117367260363
# short: price-6339.0, vol-73111.0
# sell short: price-6344.0, vol-301309.0, profit: 7.234746265641206
# short: price-6344.5, vol-437027.0
# sell short: price-6342.0, vol-148869.0, profit: 7.428916512994988
# short: price-6358.5, vol-196522.0
# sell short: price-6356.0, vol-137862.0, profit: 7.622582897947041
# short: price-6363.5, vol-311947.0
# sell short: price-6356.0, vol-137078.0, profit: 8.202897289125701
# short: price-6358.5, vol-80387.0
# sell short: price-6357.0, vol-175377.0, profit: 8.318914534398345
# short: price-6373.0, vol-199228.0
# sell short: price-6370.0, vol-658528.0, profit: 8.55036648111053
# short: price-6370.5, vol-109664.0
# sell short: price-6362.0, vol-207471.0, profit: 9.206095526697311
# short: price-6360.5, vol-128590.0
# sell short: price-6357.5, vol-51675.0, profit: 9.437583886640653
# short: price-6361.0, vol-487601.0
# sell short: price-6353.5, vol-108774.0, profit: 10.015986358083865
# short: price-6355.5, vol-279935.0
# sell short: price-6351.5, vol-112843.0, profit: 10.324370600797693
# short: price-6355.5, vol-281167.0
# sell short: price-6353.0, vol-166550.0, profit: 10.516989446442892
# short: price-6354.5, vol-598051.0
# sell short: price-6346.0, vol-538242.0, profit: 11.171738929440039
# short: price-6342.5, vol-4909.0
# sell short: price-6343.5, vol-124879.0, profit: 11.094667071171102
# short: price-6345.5, vol-139813.0
# sell short: price-6344.5, vol-252940.0, profit: 11.171714637624348
# short: price-6350.0, vol-8024.0
# sell short: price-6348.5, vol-811679.0, profit: 11.287185886135148
# short: price-6347.0, vol-73330.0
# sell short: price-6343.5, vol-98486.0, profit: 11.55668247498005
# short: price-6347.0, vol-158711.0
# sell short: price-6339.5, vol-218267.0, profit: 12.133856711853753
# short: price-6341.5, vol-534402.0
# sell short: price-6340.0, vol-178189.0, profit: 12.249255153063586
# short: price-6345.5, vol-143876.0
# sell short: price-6338.5, vol-192295.0, profit: 12.787314441366902
# short: price-6333.5, vol-93522.0
# sell short: price-6332.0, vol-111109.0, profit: 12.902703882961248
# short: price-6331.0, vol-570470.0
# sell short: price-6328.0, vol-460153.0, profit: 13.133519218350727
# short: price-6326.0, vol-96455.0
# sell short: price-6317.0, vol-152558.0, profit: 13.826184145166224
# short: price-6321.5, vol-591986.0
# sell short: price-6319.5, vol-50905.0, profit: 13.98000011158399
# short: price-6324.0, vol-113613.0
# sell short: price-6324.5, vol-82171.0, profit: 13.941573482876834
# short: price-6336.5, vol-10212.0
# sell short: price-6336.0, vol-159758.0, profit: 13.979927339620872
# short: price-6335.0, vol-33278.0
# sell short: price-6334.0, vol-63174.0, profit: 14.056647161666717
# short: price-6334.0, vol-65365.0
# sell short: price-6331.0, vol-184858.0, profit: 14.286806627804253
# short: price-6332.5, vol-158602.0
# sell short: price-6324.0, vol-200627.0, profit: 14.93877064575355
# short: price-6328.0, vol-27038.0
# sell short: price-6323.5, vol-58293.0, profit: 15.283709889131273
# short: price-6333.0, vol-300090.0
# sell short: price-6334.0, vol-207140.0, profit: 15.207171709735917
# short: price-6333.0, vol-19747.0
# sell short: price-6331.0, vol-42414.0, profit: 15.360272239750259
# short: price-6331.0, vol-366302.0
# sell short: price-6331.5, vol-868978.0, profit: 15.32199710724666
# short: price-6342.5, vol-454765.0
# sell short: price-6339.0, vol-219836.0, profit: 15.589458362291907
# short: price-6337.5, vol-53656.0
# sell short: price-6323.5, vol-80391.0, profit: 16.659556600229223
# short: price-6334.5, vol-234294.0
# sell short: price-6330.5, vol-113278.0, profit: 16.96476802553491
# short: price-6337.5, vol-71758.0
# sell short: price-6337.0, vol-219778.0, profit: 17.002877314053592
# short: price-6351.5, vol-49630.0
# sell short: price-6348.5, vol-349684.0, profit: 17.231011041213776
# short: price-6347.0, vol-12359.0
# sell short: price-6341.5, vol-202134.0, profit: 17.649355052443184
# short: price-6336.5, vol-55893.0
# sell short: price-6337.0, vol-14256.0, profit: 17.611293769010103
# short: price-6341.5, vol-33272.0
# sell short: price-6340.5, vol-544518.0, profit: 17.68736231844332
# short: price-6339.0, vol-192869.0
# sell short: price-6339.5, vol-299802.0, profit: 17.649319043661706
# short: price-6343.0, vol-154342.0
# net return: 17.649319043661706

# %%
44.820041660407924*30*6
# Out:
# 8067.607498873426

# %%
import requests
import json
from sklearn.externals import joblib
clf1 = joblib.load('order_book_flow.joblib')

# %%
while True:
    res = requests.get('http://localhost:4444/orderBookL2?symbol=XBTUSD')
    ob = res.json()
    asks = filter(lambda item: item['side'] == 'Sell', ob)
    asks = sorted(asks, key=lambda a: a['price'])[:10]
    bids = filter(lambda item: item['side'] == 'Buy', ob)
    bids = sorted(bids, key=lambda b: b['price'], reverse=True)[:10]
    row = {}
    for index, val in enumerate(asks):
        ind = str(index)
        row['ask_p_' + ind] = val['price']
        row['ask_vol_' + ind] = val['size']
    for index, val in enumerate(bids):
        ind = str(index)
        row['bid_p_' + ind] = val['price']
        row['bid_vol_' + ind] = val['size']
    df = pd.DataFrame(row)
    df = feature(df)
    pred = clf.predict(df)
    
    best_bid = row['bid_p_0']
    best_ask = row['ask_p_0']
    if descision == 1:
        if long is None:
            long = best_ask
            xbt = amount / long
            print('bid: {0}'.format(long))
    elif descision == -1:
        if long is not None:
            tmp = xbt * best_bid
            profit += (tmp - amount)
            amount = tmp
            print('ask: {0}, profit: {1}'.format(best_bid, profit))
            long = None
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-25-2df6a52a9998> in <module>
#       1 while True:
#       2     res = requests.get('http://localhost:4444/orderBookL2?symbol=XBTUSD')
# ----> 3     ob = res.json()
#       4     asks = filter(lambda item: item['side'] == 'Sell', ob)
#       5     asks = sorted(asks, key=lambda a: a['price'])[:10]
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from sklearn.externals import joblib
joblib.dump(clf, 'order_book_flow.joblib')
# Out:
# ['order_book_flow.joblib']

# %%
clf1 = joblib.load('order_book_flow.joblib')

# %%
clf1.predict(X.head(1))
# Out:
# array([0])
